# %% [markdown]
# ### 1. Градиентный спуск
#
# В данном разделе предстоит минимизировать функцию $$ f(x, y) = x^2 + y^2 $$ при помощи метода градиентного спуска

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import warnings

warnings.filterwarnings(action='ignore')

# %% [markdown]
# Задание 1. Реализуйте функцию gradient_vector таким образом, чтобы она возвращала градиент заданной функции f(x, y)
#
# должен возвращаться numpy array, содержащий 2 numpy array (производные по x и y)

# %%
def gradient_vector(x: np.array, y: np.array) -> np.array:
     return np.array([2 * x, 2 * y])

# %% [markdown]
# Задание 2. Реализуйте обновление координат найденного экстремума методом градиентного спуска.

# %%
def gradient_descent(vector, lr=0.001, epsilon=0.001, stop_iteration=10000):
    """

    Args:
        vector (np.array): исходные занчения аргументво x, y
        lr (float, optional): learning rate. Коэффициент скорости обучения.
        epsilon (float, optional): Допустимая погрешность
        stop_iteration (int, optional): количество итераций

    Returns:
        np.array, содержащий координаты экстремума, номер итерации, градиенты x, y, значения отклонений от истинного значения
    """
    iteration = 1

    x_gradient = np.array([])
    y_gradient =  np.array([])
    loss =  np.array([])

    extremum = vector

    x_gradient = np.append(x_gradient, extremum[0])
    y_gradient = np.append(y_gradient, extremum[1])

    while np.linalg.norm(np.subtract(extremum[0], extremum[1])) > epsilon:
        loss = np.append(loss, np.absolute(vector[0]-extremum[0]))
        vector = extremum

        extremum = vector - lr * gradient_vector(extremum[0], extremum[1])

        x_gradient = np.append(x_gradient, extremum[0])
        y_gradient = np.append(y_gradient, extremum[1])

        iteration = iteration + 1
        if iteration == stop_iteration:
            break

    return extremum, iteration, x_gradient, y_gradient, loss

# %%
def plot_contour(x_gradient, y_gradient, vector):
    """
    Визуализация поиска точки экстремума
    """
    figure, ax = plt.subplots(1, 1, figsize=(10, 5))
    sns.set_theme(style='whitegrid', palette='pastel')

    contour = plt.contour(X, Y, Z, cmap=cm.RdBu)
    plt.clabel(contour, fontsize=10)

    ax.text(x=vector[0]+0.05, y=vector[1]-0.25, s='start', c='r')
    plt.plot(vector[0], vector[1], 'ro')

    ax.text(x=x_gradient[-1]+0.05, y=y_gradient[-1]-0.25, s='finish', c='b')
    plt.plot(x_gradient, y_gradient, 'bo')

    plt.show()

# %%
def plot_loss(loss):
    figure, ax = plt.subplots(1, 1, figsize=(10, 5))
    sns.set_theme(style='whitegrid', palette='pastel')

    ax = sns.lineplot(data=loss)
    ax.set(xlabel='Iteration')
    ax.set(ylabel='Value')
    ax.set_title('Losses')

    plt.show()

# %% [markdown]
# Инициализация функции для поиска точки экстремума, генерация значений функции.

# %% [markdown]
# $$   f(x, y) = x^2 + y^2 $$

# %%
def f(x, y):
    return np.power(x, 2) + np.power(y, 2)

x = np.arange(-2, 2, 0.1)
y = np.arange(-2, 2, 0.1)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %% [markdown]
# 3. Воспользуйтесь полученной функцией

# %%
vector = np.array([-1.5, 1.5])
extremum, iteration, gdx_gradient, gdy_gradient, loss = gradient_descent(vector)

# %% [markdown]
# Визуализация градиентного спуска

# %%
print('Function extremum reached at point: ({:.5f}, {:.5f}).'.format(extremum[0], extremum[1]))
print('Number of iterations: {}.'.format(iteration))

plot_contour(gdx_gradient, gdy_gradient, vector)
# Out:
# Function extremum reached at point: (-0.00050, 0.00050).
# Number of iterations: 4001.

# %% [markdown]
# Визуализация функции потерь

# %%
plot_loss(loss)

# %% [markdown]
# ### 2. Реализация нейронной сети для решения задачи классификации

# %%
# !wget  -O 'WineQT.csv' -q 'https://www.dropbox.com/scl/fi/qsacgxfmrio4d8crvksad/WineQT.csv?rlkey=o8mb42t8mfru5o9llgu98cxn6&dl=0'

# %%
import numpy as np
import pandas as pd

import torch
import torch.nn as nn

from tqdm import tqdm

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('WineQT.csv')

# %% [markdown]
# **Колонки**
#
# - fixed acidity
# - volatile acidity
# - citric acid
# - residual sugar
# - chlorides
# - free sulfur dioxide
# - total sulfur dioxide
# - density
# - pH
# - sulphates
# - alcohol
# - **quality (Target)** : score between 0 and 10
# - Id

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %% [markdown]
# Разделение на обучающую и тестовую выборки

# %%
df_train, df_val = train_test_split(df, test_size = 0.2, random_state = 17)

X_train = df_train.drop(['quality', 'Id'], axis=1)
X_val = df_val.drop(['quality', 'Id'], axis=1)

y_train = df_train['quality']
y_val = df_val['quality']

# %% [markdown]
# Задание 4. Примените RabustScaler для стандартизации X_train, X_val

# %%
scaler = RobustScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)

# %% [markdown]
# Преобразование значений к тензорам, для дальнейшей работы с pyTorch

# %%
X_train_ts = torch.FloatTensor(X_train)
X_val_ts = torch.FloatTensor(X_val)

y_train_ts = torch.LongTensor(y_train.values)
y_val_ts = torch.LongTensor(y_val.values)

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()

        self.fc1 = nn.Linear(X_train_ts.shape[1], 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 32)
        self.fc4 = nn.Linear(32, 11)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)

        x = self.fc2(x)
        x = self.relu(x)

        x = self.fc3(x)
        x = self.relu(x)

        output = self.fc4(x)
        return output

# %%
model = DNN()

loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# Задание 5. Заполните пропуски функции train_model
#
# 1) Инициализируйте оптимизатор ADAM.
#
# 2) Воспользуйтесь методом zero_grad
#
# 3) Вычислите градиенты функции потерь по параметрам модели, используя метод обратного распространения ошибки. backward
#
# 4) Обновите значения оптимизатора. step

# %%
def train_model(model, lr=1e-3, n_epoch=500):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    train_losses = []
    val_losses = []

    train_scores = []
    val_scores = []

    for epoch in range(1, n_epoch+1):
        model.train()
        out = model(X_train_ts)
        loss = loss_fn(out, y_train_ts)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        acc = (torch.argmax(out, dim=1) == y_train_ts).float().mean().item()

        model.eval()
        with torch.no_grad():
            out_val = model(X_val_ts)
            loss_val = loss_fn(out_val, y_val_ts)
            acc_val = (torch.argmax(out_val, dim=1) == y_val_ts).float().mean().item()

            train_losses.append(loss.item())
            val_losses.append(loss_val.item())

            train_scores.append(acc)
            val_scores.append(acc_val)

        if epoch % 20 == 0:
            print('Epoch : {:3d} / {}, Loss : {:.4f}, Accuracy : {:.2f} %, Val Loss : {:.4f}, Val Accuracy : {:.2f} %'.format(
                epoch, n_epoch, loss.item(), acc*100, loss_val.item(), acc_val*100))

    plt.plot(train_scores)
    plt.plot(val_scores)
    return train_losses, val_losses, train_losses, val_scores

# %%
train_model(model, n_epoch=750);
# Out:
# Epoch :  20 / 750, Loss : 1.6521, Accuracy : 48.58 %, Val Loss : 1.5659, Val Accuracy : 54.15 %
# Epoch :  40 / 750, Loss : 1.2122, Accuracy : 56.89 %, Val Loss : 1.1406, Val Accuracy : 60.70 %
# Epoch :  60 / 750, Loss : 1.0712, Accuracy : 60.18 %, Val Loss : 1.0133, Val Accuracy : 62.88 %
# Epoch :  80 / 750, Loss : 0.9759, Accuracy : 60.50 %, Val Loss : 0.9528, Val Accuracy : 63.76 %
# Epoch : 100 / 750, Loss : 0.9117, Accuracy : 63.24 %, Val Loss : 0.9274, Val Accuracy : 64.19 %
# Epoch : 120 / 750, Loss : 0.8638, Accuracy : 64.44 %, Val Loss : 0.9158, Val Accuracy : 62.88 %
# Epoch : 140 / 750, Loss : 0.8250, Accuracy : 66.30 %, Val Loss : 0.9146, Val Accuracy : 62.45 %
# Epoch : 160 / 750, Loss : 0.7869, Accuracy : 68.82 %, Val Loss : 0.9162, Val Accuracy : 62.01 %
# Epoch : 180 / 750, Loss : 0.7459, Accuracy : 70.79 %, Val Loss : 0.9274, Val Accuracy : 61.14 %
# Epoch : 200 / 750, Loss : 0.6999, Accuracy : 72.76 %, Val Loss : 0.9470, Val Accuracy : 61.57 %
# Epoch : 220 / 750, Loss : 0.6458, Accuracy : 76.15 %, Val Loss : 0.9859, Val Accuracy : 61.57 %
# Epoch : 240 / 750, Loss : 0.5852, Accuracy : 79.21 %, Val Loss : 1.0321, Val Accuracy : 62.45 %
# Epoch : 260 / 750, Loss : 0.5242, Accuracy : 82.71 %, Val Loss : 1.0925, Val Accuracy : 60.70 %
# Epoch : 280 / 750, Loss : 0.4660, Accuracy : 84.46 %, Val Loss : 1.1778, Val Accuracy : 61.14 %
# Epoch : 300 / 750, Loss : 0.4128, Accuracy : 86.11 %, Val Loss : 1.2618, Val Accuracy : 58.95 %
# Epoch : 320 / 750, Loss : 0.3642, Accuracy : 88.84 %, Val Loss : 1.3401, Val Accuracy : 58.95 %
# Epoch : 340 / 750, Loss : 0.3170, Accuracy : 90.81 %, Val Loss : 1.4537, Val Accuracy : 56.33 %
# Epoch : 360 / 750, Loss : 0.2753, Accuracy : 92.23 %, Val Loss : 1.5688, Val Accuracy : 57.64 %
# Epoch : 380 / 750, Loss : 0.2359, Accuracy : 93.33 %, Val Loss : 1.7035, Val Accuracy : 57.64 %
# Epoch : 400 / 750, Loss : 0.2004, Accuracy : 94.97 %, Val Loss : 1.8504, Val Accuracy : 58.52 %
# Epoch : 420 / 750, Loss : 0.1684, Accuracy : 96.39 %, Val Loss : 1.9983, Val Accuracy : 58.95 %
# Epoch : 440 / 750, Loss : 0.1397, Accuracy : 96.83 %, Val Loss : 2.1528, Val Accuracy : 59.39 %
# Epoch : 460 / 750, Loss : 0.1153, Accuracy : 97.48 %, Val Loss : 2.3140, Val Accuracy : 58.95 %
# Epoch : 480 / 750, Loss : 0.0946, Accuracy : 98.14 %, Val Loss : 2.4492, Val Accuracy : 59.39 %
# Epoch : 500 / 750, Loss : 0.0774, Accuracy : 98.58 %, Val Loss : 2.5947, Val Accuracy : 58.95 %
# Epoch : 520 / 750, Loss : 0.0632, Accuracy : 98.91 %, Val Loss : 2.7460, Val Accuracy : 59.39 %
# Epoch : 540 / 750, Loss : 0.0518, Accuracy : 99.34 %, Val Loss : 2.8866, Val Accuracy : 58.95 %
# Epoch : 560 / 750, Loss : 0.0427, Accuracy : 99.56 %, Val Loss : 3.0272, Val Accuracy : 58.95 %
# Epoch : 580 / 750, Loss : 0.0354, Accuracy : 99.78 %, Val Loss : 3.1606, Val Accuracy : 58.52 %
# Epoch : 600 / 750, Loss : 0.0296, Accuracy : 99.89 %, Val Loss : 3.2745, Val Accuracy : 58.52 %
# Epoch : 620 / 750, Loss : 0.0250, Accuracy : 99.89 %, Val Loss : 3.3881, Val Accuracy : 58.95 %
# Epoch : 640 / 750, Loss : 0.0213, Accuracy : 100.00 %, Val Loss : 3.4897, Val Accuracy : 58.95 %
# Epoch : 660 / 750, Loss : 0.0183, Accuracy : 100.00 %, Val Loss : 3.5858, Val Accuracy : 58.52 %
# Epoch : 680 / 750, Loss : 0.0158, Accuracy : 100.00 %, Val Loss : 3.6789, Val Accuracy : 58.52 %
# Epoch : 700 / 750, Loss : 0.0138, Accuracy : 100.00 %, Val Loss : 3.7637, Val Accuracy : 58.52 %
# Epoch : 720 / 750, Loss : 0.0121, Accuracy : 100.00 %, Val Loss : 3.8444, Val Accuracy : 58.52 %
# Epoch : 740 / 750, Loss : 0.0108, Accuracy : 100.00 %, Val Loss : 3.9200, Val Accuracy : 58.52 %

# %% [markdown]
# Можно наблюдать переобучение, так как при росте точности на обучающей выборке, на валидационной ее значение начало снижаться

# %% [markdown]
# Задание 6. Проверьте различные конфигурации (число слоев, их размер) модели DNN.
#
# Можете также опробовать различное число эпох и значения learning_rate при обучении.
#
# Требуется найти такую конфигурацию, при которой переобучения не будет

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()

        self.fc1 = nn.Linear(X_train_ts.shape[1], 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 32)
        self.fc4 = nn.Linear(32, 11)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)

        x = self.fc2(x)
        x = self.relu(x)

        x = self.fc3(x)
        x = self.relu(x)

        output = self.fc4(x)
        return output

# %%
model = DNN()

loss_fn = nn.CrossEntropyLoss()

train_model(model, lr=1e-4, n_epoch=1000);
# Out:
# Epoch :  20 / 1000, Loss : 2.4095, Accuracy : 2.19 %, Val Loss : 2.3952, Val Accuracy : 3.93 %
# Epoch :  40 / 1000, Loss : 2.3369, Accuracy : 6.24 %, Val Loss : 2.3170, Val Accuracy : 8.73 %
# Epoch :  60 / 1000, Loss : 2.2382, Accuracy : 21.77 %, Val Loss : 2.2115, Val Accuracy : 22.71 %
# Epoch :  80 / 1000, Loss : 2.1131, Accuracy : 43.00 %, Val Loss : 2.0792, Val Accuracy : 46.29 %
# Epoch : 100 / 1000, Loss : 1.9662, Accuracy : 50.55 %, Val Loss : 1.9261, Val Accuracy : 54.59 %
# Epoch : 120 / 1000, Loss : 1.8045, Accuracy : 52.30 %, Val Loss : 1.7600, Val Accuracy : 52.40 %
# Epoch : 140 / 1000, Loss : 1.6471, Accuracy : 54.27 %, Val Loss : 1.6016, Val Accuracy : 55.90 %
# Epoch : 160 / 1000, Loss : 1.5160, Accuracy : 56.02 %, Val Loss : 1.4710, Val Accuracy : 60.26 %
# Epoch : 180 / 1000, Loss : 1.4189, Accuracy : 55.69 %, Val Loss : 1.3746, Val Accuracy : 60.26 %
# Epoch : 200 / 1000, Loss : 1.3510, Accuracy : 57.44 %, Val Loss : 1.3061, Val Accuracy : 62.45 %
# Epoch : 220 / 1000, Loss : 1.3014, Accuracy : 57.00 %, Val Loss : 1.2558, Val Accuracy : 61.14 %
# Epoch : 240 / 1000, Loss : 1.2614, Accuracy : 57.99 %, Val Loss : 1.2147, Val Accuracy : 61.57 %
# Epoch : 260 / 1000, Loss : 1.2274, Accuracy : 58.10 %, Val Loss : 1.1799, Val Accuracy : 62.45 %
# Epoch : 280 / 1000, Loss : 1.1967, Accuracy : 58.42 %, Val Loss : 1.1484, Val Accuracy : 62.88 %
# Epoch : 300 / 1000, Loss : 1.1689, Accuracy : 57.88 %, Val Loss : 1.1196, Val Accuracy : 62.01 %
# Epoch : 320 / 1000, Loss : 1.1433, Accuracy : 57.77 %, Val Loss : 1.0928, Val Accuracy : 61.14 %
# Epoch : 340 / 1000, Loss : 1.1199, Accuracy : 57.55 %, Val Loss : 1.0679, Val Accuracy : 61.14 %
# Epoch : 360 / 1000, Loss : 1.0988, Accuracy : 57.99 %, Val Loss : 1.0455, Val Accuracy : 61.14 %
# Epoch : 380 / 1000, Loss : 1.0801, Accuracy : 57.55 %, Val Loss : 1.0257, Val Accuracy : 61.14 %
# Epoch : 400 / 1000, Loss : 1.0634, Accuracy : 58.10 %, Val Loss : 1.0087, Val Accuracy : 61.14 %
# Epoch : 420 / 1000, Loss : 1.0486, Accuracy : 58.32 %, Val Loss : 0.9942, Val Accuracy : 63.32 %
# Epoch : 440 / 1000, Loss : 1.0353, Accuracy : 58.97 %, Val Loss : 0.9821, Val Accuracy : 63.76 %
# Epoch : 460 / 1000, Loss : 1.0234, Accuracy : 59.41 %, Val Loss : 0.9721, Val Accuracy : 64.19 %
# Epoch : 480 / 1000, Loss : 1.0124, Accuracy : 60.07 %, Val Loss : 0.9637, Val Accuracy : 64.19 %
# Epoch : 500 / 1000, Loss : 1.0023, Accuracy : 60.72 %, Val Loss : 0.9566, Val Accuracy : 64.63 %
# Epoch : 520 / 1000, Loss : 0.9928, Accuracy : 60.50 %, Val Loss : 0.9505, Val Accuracy : 66.38 %
# Epoch : 540 / 1000, Loss : 0.9839, Accuracy : 61.71 %, Val Loss : 0.9454, Val Accuracy : 65.94 %
# Epoch : 560 / 1000, Loss : 0.9755, Accuracy : 61.93 %, Val Loss : 0.9409, Val Accuracy : 65.50 %
# Epoch : 580 / 1000, Loss : 0.9674, Accuracy : 62.36 %, Val Loss : 0.9371, Val Accuracy : 65.94 %
# Epoch : 600 / 1000, Loss : 0.9597, Accuracy : 62.69 %, Val Loss : 0.9337, Val Accuracy : 66.38 %
# Epoch : 620 / 1000, Loss : 0.9524, Accuracy : 62.80 %, Val Loss : 0.9306, Val Accuracy : 65.07 %
# Epoch : 640 / 1000, Loss : 0.9453, Accuracy : 63.35 %, Val Loss : 0.9278, Val Accuracy : 65.07 %
# Epoch : 660 / 1000, Loss : 0.9384, Accuracy : 63.46 %, Val Loss : 0.9255, Val Accuracy : 64.63 %
# Epoch : 680 / 1000, Loss : 0.9317, Accuracy : 63.46 %, Val Loss : 0.9238, Val Accuracy : 64.63 %
# Epoch : 700 / 1000, Loss : 0.9252, Accuracy : 63.68 %, Val Loss : 0.9220, Val Accuracy : 64.19 %
# Epoch : 720 / 1000, Loss : 0.9189, Accuracy : 64.22 %, Val Loss : 0.9204, Val Accuracy : 64.19 %
# Epoch : 740 / 1000, Loss : 0.9128, Accuracy : 64.44 %, Val Loss : 0.9191, Val Accuracy : 64.63 %
# Epoch : 760 / 1000, Loss : 0.9069, Accuracy : 64.66 %, Val Loss : 0.9182, Val Accuracy : 64.63 %
# Epoch : 780 / 1000, Loss : 0.9011, Accuracy : 64.55 %, Val Loss : 0.9177, Val Accuracy : 63.32 %
# Epoch : 800 / 1000, Loss : 0.8957, Accuracy : 64.77 %, Val Loss : 0.9171, Val Accuracy : 62.88 %
# Epoch : 820 / 1000, Loss : 0.8905, Accuracy : 64.77 %, Val Loss : 0.9164, Val Accuracy : 62.88 %
# Epoch : 840 / 1000, Loss : 0.8854, Accuracy : 64.77 %, Val Loss : 0.9159, Val Accuracy : 62.88 %
# Epoch : 860 / 1000, Loss : 0.8805, Accuracy : 64.77 %, Val Loss : 0.9155, Val Accuracy : 62.88 %
# Epoch : 880 / 1000, Loss : 0.8755, Accuracy : 64.77 %, Val Loss : 0.9151, Val Accuracy : 62.01 %
# Epoch : 900 / 1000, Loss : 0.8707, Accuracy : 65.21 %, Val Loss : 0.9150, Val Accuracy : 62.45 %
# Epoch : 920 / 1000, Loss : 0.8658, Accuracy : 65.75 %, Val Loss : 0.9151, Val Accuracy : 62.45 %
# Epoch : 940 / 1000, Loss : 0.8610, Accuracy : 65.97 %, Val Loss : 0.9149, Val Accuracy : 62.45 %
# Epoch : 960 / 1000, Loss : 0.8562, Accuracy : 66.41 %, Val Loss : 0.9148, Val Accuracy : 62.45 %
# Epoch : 980 / 1000, Loss : 0.8516, Accuracy : 66.41 %, Val Loss : 0.9146, Val Accuracy : 62.45 %
# Epoch : 1000 / 1000, Loss : 0.8471, Accuracy : 66.52 %, Val Loss : 0.9146, Val Accuracy : 62.01 %
